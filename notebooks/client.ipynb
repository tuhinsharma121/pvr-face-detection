# %%
# %%time

import requests
import base64



url = "http://127.0.0.1:5000/predict"
filename = "sample.jpg"
image = open(filename, 'rb') #open binary file in read mode image_read = image.read() image_64_encode = base64.encodestring(image_read)
image_read = image.read() 
image_64_encode = base64.encodebytes(image_read).decode('utf-8')
#image_64_encode = """..."""


data = {"image": image_64_encode}

r = requests.post(url, json=data)
print(r.text)

# %%
# %%time

import requests
import base64
from PIL import Image
import json

url = "http://127.0.0.1:6006/predict"
filename = "sample.jpg"
image = open(filename, 'rb') 
image_read = image.read() 
image_64_encode = base64.encodebytes(image_read).decode('utf-8')


data = {"image": image_64_encode}

r = requests.post(url, json=data)
print(r.text)

response_json = json.loads(r.text)
for i in range(len(response_json)):
    top, right, bottom, left = response_json[i]['bounding_box']
    im = Image.open(filename)
    im = im.crop((left, top, right, bottom))
    im.save('cropped_'+str(i)+'.png')

# %%
url = 'http://127.0.0.1:5000/food/2'
req = requests.get(url)
req.content

# %%
url = 'http://127.0.0.1:6006/food/2'
req = requests.get(url)
req.content

# %%
url = 'http://127.0.0.1:5000/movies/2'
req = requests.get(url)
req.content

# %%
url = 'http://127.0.0.1:6006/movies/2'
req = requests.get(url)
req.content

# %%
# %%time

import requests
import base64



url = "http://ec2-34-207-239-159.compute-1.amazonaws.com/predict"
data = {"image": image_64_encode}

filename = "sample.jpg"
image = open(filename, 'rb') #open binary file in read mode image_read = image.read() image_64_encode = base64.encodestring(image_read)
image_read = image.read() 
image_64_encode = base64.encodebytes(image_read).decode('utf-8')
#image_64_encode = """..."""


data = {"image": image_64_encode}

r = requests.post(url, json=data)
print(r.text)

# %%
# %%time

url = 'http://ec2-34-207-239-159.compute-1.amazonaws.com/food/2'
req = requests.get(url)
print(req.content)

# %%
# %%time

url = 'http://ec2-34-207-239-159.compute-1.amazonaws.com/movies/2'
req = requests.get(url)
print(req.content)

# %%
import cv2
import numpy as np
# %matplotlib inline
img = cv2.imread('faces/1527602940693.jpg')

img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# equalize the histogram of the Y channel
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# convert the YUV image back to RGB format
img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

cv2.imshow('Color input image', img)
cv2.imshow('Histogram equalized', img_output)
